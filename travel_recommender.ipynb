# %% [markdown]
# <a href="https://colab.research.google.com/github/Ekansh-Patidar/travel-recommender/blob/main/travel_recommender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os

folders = [
    "data",
    "notebooks",
    "app",
    "models"
]

for folder in folders:
    os.makedirs(folder, exist_ok=True)

print("Folder structure created!")
# Out:
# Folder structure created!
